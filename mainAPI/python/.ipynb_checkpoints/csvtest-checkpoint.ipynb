# %%
from bottle import route, run, HTTPResponse
import requests
import csv
import json

# %%
def csvreader(fileaddr = '../data/test.csv'):
    csvlist = []
    with open(fileaddr, 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            csvlist.append((row[0],row[1]))
    
    return csvlist

# %%
@route('/exchangetest')
def hello2():
    message = 'そマ? テンサゲ～'
    exchange_tapple = csvreader()
    for before, after in exchange_tapple:
        message = message.replace(before, after)
    
    print(message)
    body = {"status": "OK", "message": message}
    r = HTTPResponse(status=200, body=body)
    r.set_header("Content-Type", "application/json")
    return r

# %%
run(host='0.0.0.0', port=8080, debug=True)
# Out:
# Bottle v0.12.13 server starting up (using WSGIRefServer())...
# Listening on http://0.0.0.0:8080/
# Hit Ctrl-C to quit.
#
# 183.74.193.16 - - [21/Oct/2017 05:20:11] "GET /exchangetest HTTP/1.1" 200 117
# 183.74.193.16 - - [21/Oct/2017 05:22:00] "GET /exchangetest HTTP/1.1" 200 117
# ----------------------------------------
# Exception happened during processing of request from ('183.74.193.16', 49800)
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/simple_server.py", line 118, in handle
#     self.raw_requestline = self.rfile.readline(65537)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('183.74.193.16', 49803)
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/simple_server.py", line 118, in handle
#     self.raw_requestline = self.rfile.readline(65537)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
# /home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/bottle.py:3468: DeprecationWarning: Flags not at the start of the expression "((?m)[urbURB]?(?:''(" (truncated)
#   patterns = [re.compile(p%pattern_vars) for p in patterns]
# /home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/bottle.py:3468: DeprecationWarning: Flags not at the start of the expression '\\{\\{((?:((?m)[urbURB' (truncated)
#   patterns = [re.compile(p%pattern_vars) for p in patterns]
# 183.74.193.16 - - [21/Oct/2017 05:22:28] "GET /favicon.ico HTTP/1.1" 404 746
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 138, in run
#     self.finish_response()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 180, in finish_response
#     self.write(data)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 274, in write
#     self.send_headers()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 332, in send_headers
#     self.send_preamble()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 252, in send_preamble
#     self._write(('HTTP/%s %s\r\n' % (self.http_version,self.status)).encode('iso-8859-1'))
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 453, in _write
#     result = self.stdout.write(data)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 775, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# 183.74.193.16 - - [21/Oct/2017 05:22:28] "GET /favicon.ico HTTP/1.1" 500 59
# ----------------------------------------
# Exception happened during processing of request from ('183.74.193.16', 49802)
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 138, in run
#     self.finish_response()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 180, in finish_response
#     self.write(data)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 274, in write
#     self.send_headers()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 332, in send_headers
#     self.send_preamble()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 252, in send_preamble
#     self._write(('HTTP/%s %s\r\n' % (self.http_version,self.status)).encode('iso-8859-1'))
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 453, in _write
#     result = self.stdout.write(data)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 775, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 141, in run
#     self.handle_error()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 368, in handle_error
#     self.finish_response()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 180, in finish_response
#     self.write(data)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 274, in write
#     self.send_headers()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 331, in send_headers
#     if not self.origin_server or self.client_is_modern():
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 344, in client_is_modern
#     return self.environ['SERVER_PROTOCOL'].upper() != 'HTTP/0.9'
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/simple_server.py", line 133, in handle
#     handler.run(self.server.get_app())
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/handlers.py", line 144, in run
#     self.close()
#   File "/home/ubuntu/.pyenv/versions/anaconda3-5.0.0/lib/python3.6/wsgiref/simple_server.py", line 35, in close
#     self.status.split(' ',1)[0], self.bytes_sent
# AttributeError: 'NoneType' object has no attribute 'split'
# ----------------------------------------
# 183.74.193.16 - - [21/Oct/2017 05:22:54] "GET /hello HTTP/1.1" 404 734
